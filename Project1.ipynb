# %%
from googleapiclient.discovery import build

api_key = 'AIzaSyDYMFiNaA8Iz7TDwEoKpsRvvFV3Kw-_DMc'

def video_comments(video_id):
# empty list for storing reply
    replies = []

# creating youtube resource object
youtube = build('youtube', 'v3',
developerKey=api_key)

# retrieve youtube video results
video_response=youtube.commentThreads().list(
part='snippet,replies',
order='time',
videoId=video_id
).execute()

pageNum = 1



#for item in video_response["items"]:
 #   print(item.update)
    
    
# iterate video response
while video_response:
    print(len(video_response["items"]))
    print(video_response['items'][0])
# extracting required info
# from each result object
#for item in video_response['items']:

# Extracting comments
#comment = item['snippet']['topLevelComment']['snippet']['textDisplay']

# counting number of reply of comment
#replycount = item['snippet']['totalReplyCount']

# if reply is there
#if replycount>0:

# iterate through all reply
#for reply in item['replies']['comments']:

# Extract reply
#reply = reply['snippet']['textDisplay']

# Store reply is list
#replies.append(reply)

# print comment with list of reply
#print(comment, replies, end = '\n\n')

# empty reply list
#replies = []

# Again repeat
    if 'nextPageToken' in video_response:
        print(video_response['nextPageToken'])
        video_response = youtube.commentThreads().list(
            pageToken = video_response['nextPageToken'],
            part = 'snippet,replies',
            videoId = video_id
        ).execute()
        print(pageNum)
        pageNum = pageNum+1
    else:
        print("done")
        break

# Enter video id
video_id = "4j8m8L8B7pM"

# Call function
video_comments(video_id)
# Out:
# 20
# {'kind': 'youtube#commentThread', 'etag': 'XxFUyT0bH6ypixdydbXpResrFV8', 'id': 'UgwKplkzsT6FYkPQzEt4AaABAg', 'snippet': {'videoId': '4j8m8L8B7pM', 'topLevelComment': {'kind': 'youtube#comment', 'etag': '5V3DVBBVUKgkgkuXltJ0AgCAxUM', 'id': 'UgwKplkzsT6FYkPQzEt4AaABAg', 'snippet': {'videoId': '4j8m8L8B7pM', 'textDisplay': 'The only thing good about the ace ventura movies is that they had Jim Carey in them. The movies themselves are pretty bad, although I do laugh a lot watching them', 'textOriginal': 'The only thing good about the ace ventura movies is that they had Jim Carey in them. The movies themselves are pretty bad, although I do laugh a lot watching them', 'authorDisplayName': 'Pleyland', 'authorProfileImageUrl': 'https://yt3.ggpht.com/fzWGJKWO5Zd7aKnI_XH87eLUBD4yHFJvG6Y920MKt3yNyjZ5J1m8MPw4bANsx_9YdM-jeFalmg=s48-c-k-c0x00ffffff-no-rj', 'authorChannelUrl': 'http://www.youtube.com/channel/UCO8cusNnVJClMTwy5kIUSMQ', 'authorChannelId': {'value': 'UCO8cusNnVJClMTwy5kIUSMQ'}, 'canRate': True, 'viewerRating': 'none', 'likeCount': 0, 'publishedAt': '2021-10-10T17:21:40Z', 'updatedAt': '2021-10-10T17:21:40Z'}}, 'canReply': True, 'totalReplyCount': 0, 'isPublic': True}}
# QURTSl9pMUxvS3JvZlhKdklDTWdwQ0Q5RmtWTjRkTzd4QlRmU05QZnBVeXZVb0NOYlg1bHI4dlBFX2RmRXVVcEoxWnVDc2xNczdUb1Vubw==
# 1
# 20
# {'kind': 'youtube#commentThread', 'etag': 'AYi1wR-AIELsTWB7IYcFLybBoXg', 'id': 'UgzyPpSGVzDy8rH6NzB4AaABAg', 'snippet': {'videoId': '4j8m8L8B7pM', 'topLevelComment': {'kind': 'youtube#comment', 'etag': 'ck8vLdRhQFTpBhUR-R8laZEDyk8', 'id': 'UgzyPpSGVzDy8rH6NzB4AaABAg', 'snippet': {'videoId': '4j8m8L8B7pM', 'textDisplay': 'Peace of Hemorrhoids... when you have them but they don&#39;t bother you.', 'textOriginal': "Peace of Hemorrhoids... when you have them but they don't bother you.", 'authorDisplayName': 'Ivan L.', 'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLQ81U4chlO1Yg4I1QraPmD36n8abTpZPyRgwA=s48-c-k-c0x00ffffff-no-rj', 'authorChannelUrl': 'http://www.youtube.com/channel/UCZiHQKGOv_aSIshB5l7VWAA', 'authorChannelId': {'value': 'UCZiHQKGOv_aSIshB5l7VWAA'}, 'canRate': True, 'viewerRating': 'none', 'likeCount': 0, 'publishedAt': '2020-05-16T19:20:57Z', 'updatedAt': '2020-05-16T19:20:57Z'}}, 'canReply': True, 'totalReplyCount': 0, 'isPublic': True}}
# QURTSl9pMjNKbGpWWm56ODZuWTMyTHdsZWtOcE9kbjlZSHBSQUpkRVdwWk5kR3I4R3BLeTlKSldBRnBoZGJMSWxPakRjcWE5a25FU0dfOA==
# 2
# 20
# {'kind': 'youtube#commentThread', 'etag': 'D4F3-c1yFnP5Bbgoapgr57-8Opk', 'id': 'UgzFkSf29So1cMyiAOp4AaABAg', 'snippet': {'videoId': '4j8m8L8B7pM', 'topLevelComment': {'kind': 'youtube#comment', 'etag': '-RKkdHc5y5wAWVtQQ5lTa55E7yo', 'id': 'UgzFkSf29So1cMyiAOp4AaABAg', 'snippet': {'videoId': '4j8m8L8B7pM', 'textDisplay': 'Even the dolphin....', 'textOriginal': 'Even the dolphin....', 'authorDisplayName': 'GallowsPole805', 'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLRgI6MP4zIt-ZDGUuET5Y_xHA27gglJMWaVymnz=s48-c-k-c0x00ffffff-no-rj', 'authorChannelUrl': 'http://www.youtube.com/channel/UCTcFIGPaxV0rtlHQ--ywf-Q', 'authorChannelId': {'value': 'UCTcFIGPaxV0rtlHQ--ywf-Q'}, 'canRate': True, 'viewerRating': 'none', 'likeCount': 7, 'publishedAt': '2019-08-10T05:41:08Z', 'updatedAt': '2019-08-10T05:41:08Z'}}, 'canReply': True, 'totalReplyCount': 0, 'isPublic': True}}
# QURTSl9pMkx0V2d2WDRaSkdNRVNQWWZBdmZBQ0hFZk5MSlZPa3h2Nkd4bm10WHIxOHpSbmpxSzZoWVVIbFNkbHFrMDVBTWFmZW9DZ25Xdw==
# 3
# 20
# {'kind': 'youtube#commentThread', 'etag': 'svRCPY9fPsOBuN3HXH2MMZRKkZs', 'id': 'UgwU1N5d1YeJJD93jTt4AaABAg', 'snippet': {'videoId': '4j8m8L8B7pM', 'topLevelComment': {'kind': 'youtube#comment', 'etag': 'eQboxiuhBDGRUG43_WtPbj7V1tg', 'id': 'UgwU1N5d1YeJJD93jTt4AaABAg', 'snippet': {'videoId': '4j8m8L8B7pM', 'textDisplay': 'I only just found something out, one of the cops spitting in disgust was a woman. Damn, Einhorn really did make out with everyone on the force. And that copper wasn&#39;t happy that she&#39;d kissed a man.', 'textOriginal': "I only just found something out, one of the cops spitting in disgust was a woman. Damn, Einhorn really did make out with everyone on the force. And that copper wasn't happy that she'd kissed a man.", 'authorDisplayName': 'Mike Gaddass', 'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLQCKHUxXC3buKlGrHmUVamCa9UeD0vtQpx_7HDDNg=s48-c-k-c0x00ffffff-no-rj', 'authorChannelUrl': 'http://www.youtube.com/channel/UCS0kEzvzdSo1Keo8urJip7Q', 'authorChannelId': {'value': 'UCS0kEzvzdSo1Keo8urJip7Q'}, 'canRate': True, 'viewerRating': 'none', 'likeCount': 57, 'publishedAt': '2017-09-23T20:07:36Z', 'updatedAt': '2017-09-23T20:07:36Z'}}, 'canReply': True, 'totalReplyCount': 0, 'isPublic': True}}
# QURTSl9pM1VlWDBaeWI4d0Jlazk5b3FtQnZUcG85Q3BPVXFGSTFwLUdqbTR5Q0hYS213MTJnWTA1SVVzUjdTM19yTnVQQ2dVVEJPdGxkUQ==
# 4
# 2
# {'kind': 'youtube#commentThread', 'etag': 'Zm6PUz5LMcWpbIp9lI7bFfKdCPQ', 'id': 'UgwBNFIZfCI3NdzcNxl4AaABAg', 'snippet': {'videoId': '4j8m8L8B7pM', 'topLevelComment': {'kind': 'youtube#comment', 'etag': 'bf76Ny-V-uxWxJF5oA4egwq-_9Q', 'id': 'UgwBNFIZfCI3NdzcNxl4AaABAg', 'snippet': {'videoId': '4j8m8L8B7pM', 'textDisplay': 'HE FOUND CAPITAN WINKY!!!', 'textOriginal': 'HE FOUND CAPITAN WINKY!!!', 'authorDisplayName': 'Erin Fox', 'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLRJlFjr7EJT3ZRpiHt_KXL_S-DiMPRarbnc6k56Jw=s48-c-k-c0x00ffffff-no-rj', 'authorChannelUrl': 'http://www.youtube.com/channel/UCYP2DdODsk58vJSkl2b9mDA', 'authorChannelId': {'value': 'UCYP2DdODsk58vJSkl2b9mDA'}, 'canRate': True, 'viewerRating': 'none', 'likeCount': 20, 'publishedAt': '2013-06-11T00:10:36Z', 'updatedAt': '2013-06-11T00:10:36Z'}}, 'canReply': True, 'totalReplyCount': 0, 'isPublic': True}}
# done
